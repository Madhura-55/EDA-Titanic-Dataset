# %% [markdown]
# <a href="https://colab.research.google.com/github/Madhura-55/EDA-Titanic-Dataset/blob/main/Netfix-Content-Strategy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %%
sns.set_style('darkgrid')
